# %% [markdown]
# <a href="https://colab.research.google.com/github/seoloveyong-droid/-3-/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EA%B8%B0%EC%B4%88_3%EA%B0%95_%EC%8B%A4%EC%8A%B5(%EC%9B%90%EB%B3%B8)_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3강 파이썬의 이해 - 실습

# %% [markdown]
# ## 3강 1절 - 데이터 타입과 변수

# %%
53000000
# Out:
# 53000000

# %%
print("Hello World")
print("Python is fun!")
# Out:
# Hello World
# Python is fun!

# %%
1 / 3 * 3.14 * 10 * 10 * 24
3.14 * 10 * 10 + 3.14 * 10 * 26
# Out:
# 1130.4

# %% [markdown]
# ## 3강 2절 - 연산자

# %%
# 2 ** 10, 5 / 2 vs 5 // 2, 25 % 7, 8.4 % 0.9, number % 2

# %%
# max(2, 3, 4), min(2, 3, 4), round(3.141592, 2), round(3.415), abs(-3), pow(2, 3)

# %%
1 / 3 * 3.14 * 10 * 10 * 24
3.14 * 10 * 10 + 3.14 * 10 * 26
# Out:
# 1130.4

# %% [markdown]
# ## 3강 3절 - 파이썬 기초문법 상식

# %%
print((4.5 * 2 + 4.0 * 3) / (130 - 66))
# Out:
# 0.328125
